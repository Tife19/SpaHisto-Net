# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')

# ====================== PROJECT ROOT ======================
PROJECT_ROOT = Path("/content/drive/My Drive/MSC Project/SpaHisto-Net")
# ===========================================================

print("Creating folder structure for SpaHisto-Net...\n")

# Define all required folders
folders = [
    # Data folders
    "data/raw",
    "data/processed",
    "data/splits",

    # Notebooks
    "notebooks",

    # Source code (core of reproducibility)
    "src/data",
    "src/models",
    "src/training",
    "src/utils",

    # Docker folder (will be filled later)
    "docker",

    # Output folders
    "visualizations",
    "results",

    # Configuration and environment
    "configs",
    "environment",
]

# Create all folders
for folder in folders:
    path = PROJECT_ROOT / folder
    path.mkdir(parents=True, exist_ok=True)
    print(f"✅ Created: {folder}")

print("\n" + "=" * 60)
print("FOLDER STRUCTURE CREATED SUCCESSFULLY!")
print("=" * 60)

# Show final structure
print("\nFinal folder structure:")
for item in sorted(PROJECT_ROOT.iterdir()):
    if item.is_dir():
        print(f"📂 {item.name}/")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Creating folder structure for SpaHisto-Net...
#
# ✅ Created: data/raw
# ✅ Created: data/processed
# ✅ Created: data/splits
# ✅ Created: notebooks
# ✅ Created: src/data
# ✅ Created: src/models
# ✅ Created: src/training
# ✅ Created: src/utils
# ✅ Created: docker
# ✅ Created: visualizations
# ✅ Created: results
# ✅ Created: configs
# ✅ Created: environment
#
# ...
# FOLDER STRUCTURE CREATED SUCCESSFULLY!
# ...
#
# Final folder structure:
# 📂 .git/
# 📂 configs/
# 📂 data/
# 📂 docker/
# 📂 environment/
# 📂 notebooks/
# 📂 results/
# 📂 src/
# 📂 visualizations/

# %%
from pathlib import Path


PROJECT_ROOT = Path("/content/drive/My Drive/MSC Project/SpaHisto-Net")

print("Creating essential project files...\n")

# =====================================================
# 1. .gitignore
# =====================================================
gitignore_content = """# Large data files
data/raw/
data/processed/
results/
*.h5
*.h5ad
*.pt
*.pth
*.zip
*.tar.gz
*.7z

# Python
__pycache__/
*.py[cod]
*$py.class
*.so
.Python
build/
develop-eggs/
dist/
downloads/
eggs/
.eggs/
lib/
lib64/
parts/
sdist/
var/
wheels/
*.egg-info/
.installed.cfg
*.egg

# Jupyter Notebook
.ipynb_checkpoints
*.ipynb_checkpoints/

# IDEs
.vscode/
.idea/
*.swp
*.swo

# OS
.DS_Store
Thumbs.db

# Environment
.env
.venv
env/
venv/
ENV/
"""

with open(PROJECT_ROOT / ".gitignore", "w") as f:
    f.write(gitignore_content)
print("✅ Created: .gitignore")

# =====================================================
# 2. README.md
# =====================================================
readme_content = """# SpaHisto-Net

A reproducible multimodal deep learning pipeline integrating spatial transcriptomics and histopathology images for breast cancer tumor localization and gene expression prediction.

## Overview

SpaHisto-Net is a multimodal framework that combines:
- H&E histopathology image features (CNN encoder)
- Spatial transcriptomics gene expression embeddings (GNN / Graph-based encoder)
- Cross-attention fusion with contrastive learning
- Multi-task prediction heads (tumor localization + gene expression regression)

## Project Structure

```
SpaHisto-Net/
├── data/
├── notebooks/
├── src/
├── docker/
├── visualizations/
├── results/
├── configs/
├── environment/
├── .gitignore
└── README.md
```

## Getting Started

Refer to the notebooks for examples on how to use this project.
"""

with open(PROJECT_ROOT / "README.md", "w") as f:
    f.write(readme_content)
print("✅ Created: README.md")
# Out:
# Creating essential project files...
#
# ✅ Created: .gitignore
# ✅ Created: README.md

# %%
# configuring git

# !git config --global user.email "abigalabiodun019@gmail.com"
# !git config --global user.name "BeeBee"

# %%
from google.colab import drive
from pathlib import Path
import os
from google.colab import userdata

drive.mount('/content/drive')

# ====================== UPDATE THESE ======================
PROJECT_PATH = Path("/content/drive/My Drive/MSC Project/SpaHisto-Net")
GITHUB_USERNAME = "BeeBee"          # ← CHANGE THIS
GITHUB_EMAIL = "abigalabiodun019@gmail.com" # ← CHANGE THIS to your GitHub email
REPO_NAME = "SpaHisto-Net"
# ===========================================================

os.chdir(PROJECT_PATH)

print("Current directory:", os.getcwd())

# Get your GitHub Personal Access Token from Colab secrets
# Make sure you have a secret named 'GITHUB_TOKEN' in Colab's Secrets Manager.
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# Initialize Git repository (if not already initialized)
# !git init
# !git branch -M main

# Configure Git with your username and email for this repository
# !git config user.name "{GITHUB_USERNAME}"
# !git config user.email "{GITHUB_EMAIL}"

# Add the remote repository with token for authentication
GITHUB_REPO_URL = f"https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"
# !git remote remove origin || true # Remove existing origin if it exists
# !git remote add origin {GITHUB_REPO_URL}

# Add all files (respecting .gitignore)
# !git add .

# Commit
# !git commit -m "Initial commit: Project structure and essential files"

# Push to GitHub
# !git push -u origin main
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current directory: /content/drive/My Drive/MSC Project/SpaHisto-Net
# Reinitialized existing Git repository in /content/drive/My Drive/MSC Project/SpaHisto-Net/.git/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1158/1700977996.py in <cell line: 0>()
#      29
#      30 # Add the remote repository with token for authentication
# ---> 31 GITHUB_REPO_URL = f"https://{Tife19}:{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}@github.com/{Tife19}/{SpaHisto-Net}.git"
#      32 get_ipython().system('git remote remove origin || true # Remove existing origin if it exists')
#      33 get_ipython().system('git remote add origin {GITHUB_REPO_URL}')
#
# NameError: name 'Tife19' is not defined
